# %%
def generate_fashion_design(
    gender,
    occasion,
    style,
    garment,
    color,
    fabric
):

    prompt = f"""
You are an AI fashion designer.

Create a creative fashion design using:

Gender: {gender}
Occasion: {occasion}
Style: {style}
Garment: {garment}
Color: {color}
Fabric: {fabric}

Give the result with these sections:

DESIGN NAME
DESIGN CONCEPT
SILHOUETTE
FABRIC
COLOR
EMBELLISHMENT
ACCESSORIES
FOOTWEAR
STYLING
IMAGE PROMPT
"""

    response = client.models.generate_content(
        model="gemini-3.6-flash",
        contents=prompt
    )

    return response.text

# %%
# !pip install -q -U google-genai

# %%
from google import genai
from google.colab import userdata

API_KEY = userdata.get("GEMINI_API_KEY")

client = genai.Client(api_key=API_KEY)

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="Say hello in one sentence."
)

print(response.text)
# Out:
# Hello, I hope you are having a wonderful day!

# %%
from google.colab import userdata

API_KEY = userdata.get("GEMINI_API_KEY")
print("API key loaded successfully")
# Out:
# API key loaded successfully

# %% [markdown]
# ### Fashion Design Generator
#
# The `generate_fashion_design` function takes several parameters like `gender`, `occasion`, `style`, `garment`, `color`, and `fabric` to create a detailed fashion design concept. It uses the `gemini-3.6-flash` model to generate the design details, including a design name, concept, silhouette, fabric, color, embellishments, accessories, footwear, styling, and an image prompt.

# %%
import gradio as gr


def generate_design(
    gender,
    occasion,
    style,
    garment,
    color,
    fabric
):

    return generate_fashion_design(
        gender,
        occasion,
        style,
        garment,
        color,
        fabric
    )


app = gr.Interface(
    fn=generate_design,

    inputs=[
        gr.Dropdown(
            ["Women", "Men", "Unisex"],
            value="Women",
            label="Gender"
        ),

        gr.Dropdown(
            ["Wedding", "Party", "Casual", "Formal", "Festival"],
            value="Wedding",
            label="Occasion"
        ),

        gr.Dropdown(
            ["Modern Indian", "Traditional", "Modern", "Luxury"],
            value="Modern Indian",
            label="Fashion Style"
        ),

        gr.Dropdown(
            ["Lehenga", "Saree", "Kurta", "Anarkali", "Dress", "Suit"],
            value="Lehenga",
            label="Garment"
        ),

        gr.Textbox(
            value="Emerald Green",
            label="Color"
        ),

        gr.Dropdown(
            ["Silk", "Cotton", "Velvet", "Chiffon", "Organza"],
            value="Silk",
            label="Fabric"
        )
    ],

    outputs=gr.Markdown(),

    title="👗 AI Fashion Design Generator",

    description="Generate creative fashion designs using Google Gemini AI."
)

app.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ef80df5aeb030efb2e.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ef80df5aeb030efb2e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
test = generate_fashion_design(
    "Women",
    "Wedding",
    "Modern Indian",
    "Lehenga",
    "Emerald Green",
    "Silk"
)

print(test)
# Out:
# **DESIGN NAME**
# *The Emerald Canopy (Maragatha)*
#
# ---
#
# **DESIGN CONCEPT**
# "The Emerald Canopy" reinterprets classic Indian bridal couture through a lens of modern architectural elegance. Inspired by the lush, moonlit botanical gardens of ancient royal palaces, the ensemble blends opulent Indian heritage with contemporary functional luxury. Designed for the progressive modern bride, it features clean, structured cuts, lightweight high-shine embellishments, and functional modern details like hidden pockets, marrying effortless movement with regal grandiosity.
#
# ---
#
# **SILHOUETTE**
# *   **Lehenga (Skirt):** High-waisted, structured 16-panel (Kali) flare with an elongated silhouette. Includes functional concealed side pockets and a wide, reinforced horsehair-braid hemline to maintain a crisp, dramatic bell-shape without extra heavy can-can netting.
# *   **Choli (Blouse):** Sculptural corset-inspired blouse with internal boning for a tailored fit. Features a sharp sweetheart-meets-asymmetrical neckline, structured cap sleeves, and a sleek keyhole back.
# *   **Dupatta:** A dual-drape design—a lightweight silk-organza cape-style drape attached permanently to the right shoulder that cascades into a sweeping floor-length train, paired with a traditional small silk shoulder drape.
#
# ---
#
# **FABRIC**
# *   **Primary Garment:** Heavy Mulberry Raw Silk (for the lehenga skirt and choli) offering a deep, natural lustre and structural drape.
# *   **Drape/Cape:** Sheer Silk Organza and Tissue Tulle for fluid, weightless movement.
# *   **Lining:** Soft Butter Silk for breathable, skin-friendly comfort during long wedding ceremonies.
#
# ---
#
# **COLOR**
# *   **Primary Tone:** Rich, deep Emerald Green.
# *   **Accent Tones:** Antique Gold, Champagne Zari, subtle highlights of Jade Green threadwork, and brilliant Rose-Gold accents for contrast.
#
# ---
#
# **EMBELLISHMENT**
# A fusion of traditional Zardozi and 3D contemporary embroidery. The waist of the lehenga starts with structured geometric *Jaali* (lattice) embroidery in antique gold Zari, seamlessly melting into hand-stitched 3D silk-thread vines, micro-pearls, matte gold *cutdana*, and emerald Swarovski crystals that scatter down the skirt toward a dense, floral-embellished border.
#
# ---
#
# **ACCESSORIES**
# *   **Jewelry:** A multi-layered modern Polki (uncut diamond) choker with cascading Zambian emerald drops. Matching modern geometric architectural ear-cuffs and a sleek, single-strand minimalist *maang tikka*.
# *   **Waistband:** A detachable sleek metallic gold waist belt (*kamarbandh*) featuring a geometric monogram clasp to cinch the silhouette.
#
# ---
#
# **FOOTWEAR**
# Handcrafted pointed-toe mule heels wrapped in matching emerald silk, featuring gold Zardozi embroidery on the toe cap and a sturdy 3-inch block heel designed for high-end fashion appeal and all-day comfort.
#
# ---
#
# **STYLING**
# *   **Hair:** Slicked-back low architectural bun adorned with a minimalist gold leaf hairpiece or fresh white orchids.
# *   **Makeup:** Radiant, dewy skin finish, soft bronze contour, subtle emerald-tinted smoky eye with gold inner-corner highlights, and a muted warm-nude matte lipstick.
# *   **Nails:** Deep emerald green polish with fine gold-foil tips.
#
# ---
#
# **IMAGE PROMPT**
# > High-fashion bridal portrait of an Indian woman wearing a modern emerald green silk lehenga. The outfit features a high-waisted flared raw silk skirt with intricate antique gold Zardozi and 3D floral embroidery, paired with a structured, asymmetric corset blouse. She wears a floor-sweeping emerald silk-organza cape dupatta trailing behind her. Accessories include a regal Polki necklace with large emerald droplets and modern ear cuffs. Sleek low bun hairstyle, warm glowing makeup, neutral nude lips. Setting: A luxurious modern palace courtyard at twilight with warm moody architectural lighting. Professional Vogue-style fashion photography, full-length shot, 8k resolution, photorealistic, intricate fabric textures, ultra-detailed embroidery.

# %%
design_output = generate_fashion_design(
    gender="Female",
    occasion="Evening Wear",
    style="Elegant",
    garment="Gown",
    color="Midnight Blue",
    fabric="Silk"
)

print(design_output)
# Out:
# **DESIGN NAME**
# *The Celestial Nocturne Gown*
#
# ---
#
# **DESIGN CONCEPT**
# Inspired by the quiet majesty of a starlit midnight sky reflecting across still waters, *The Celestial Nocturne Gown* captures liquid fluid movement and timeless romance. It pairs structural draping with ethereal lightness, creating a look that exudes effortless royalty and understated modern elegance.
#
# ---
#
# **SILHOUETTE**
# An asymmetric, bias-cut sheath silhouette that glides seamlessly over the natural curves of the body, gently fanning out at the knee into a subtle trumpet flare with a sweeping 4-foot chapel train. The upper body features an asymmetric liquid-cowl neckline draping gracefully over one shoulder, while the back reveals a plunging low-V cut framed by ultra-fine crystal straps.
#
# ---
#
# **FABRIC**
# *   **Primary:** 100% Heavyweight Silk Charmeuse, chosen for its brilliant, water-like luster and rich, heavy drape.
# *   **Accent:** Sheer Silk Chiffon utilized for a delicate, detachable shoulder train that catches the lightest breeze.
#
# ---
#
# **COLOR**
# * Midnight Blue (a rich, deep navy with subtle sapphire and dark indigo undertones that catch the light dynamically).
#
# ---
#
# **EMBELLISHMENT**
# Intricate, gradient hand-embroidery across the bodice and down the hip, featuring micro-glass seed beads, deep sapphire Swarovski crystals, and whisper-thin silver threads arranged in an abstract constellation pattern that slowly dissipates as it reaches the hem.
#
# ---
#
# **ACCESSORIES**
# *   **Jewelry:** Platinum or white gold fine jewelry, featuring dramatic drop earrings with pear-cut blue sapphires framed by micro-pavé diamonds. A minimalist, single-strand diamond cuff.
# *   **Bag:** A sleek, hard-shell mirrored silver box clutch with a dark blue cabochon clasp.
#
# ---
#
# **FOOTWEAR**
# Strappy midnight blue silk-satin sandals with a 105mm stiletto heel, featuring a single delicate crystal-embellished ankle strap.
#
# ---
#
# **STYLING**
# *   **Hair:** Ultra-glossy Old Hollywood side-swept waves cascading over the bare shoulder.
# *   **Makeup:** Luminous, dewy skin with a soft-focus velvet finish; a subtle smoked navy eye with shimmering silver inner-corner highlights; paired with a polished nude-pink satin lip.
#
# ---
#
# **IMAGE PROMPT**
# > High-fashion editorial full-body photography of a tall, elegant female model wearing a haute couture midnight blue silk charmeuse gown. The dress features an asymmetric draped cowl neckline, a plunging low back, delicate silver micro-crystal constellation embroidery on the bodice, and a fluid bias-cut skirt with a sweeping train. Set on a grand marble balcony overlooking a European city skyline at twilight. Soft cinematic moonlit glow reflecting off the lustrous silk fabric, captured with a 85mm portrait lens, shallow depth of field, Vogue editorial style, ultra-detailed textures, highly sophisticated and dramatic atmosphere.

# %%
import gradio as gr


def generate_design(gender, occasion, style, garment, color, fabric):

    result = generate_fashion_design(
        gender,
        occasion,
        style,
        garment,
        color,
        fabric
    )

    return result


demo = gr.Interface(
    fn=generate_design,

    inputs=[
        gr.Dropdown(
            ["Women", "Men", "Unisex"],
            value="Women",
            label="Gender"
        ),

        gr.Dropdown(
            ["Wedding", "Party", "Casual", "Formal", "Festival"],
            value="Wedding",
            label="Occasion"
        ),

        gr.Dropdown(
            ["Modern Indian", "Traditional", "Modern", "Luxury"],
            value="Modern Indian",
            label="Style"
        ),

        gr.Dropdown(
            ["Lehenga", "Saree", "Kurta", "Anarkali", "Dress", "Suit"],
            value="Lehenga",
            label="Garment"
        ),

        gr.Textbox(
            value="Emerald Green",
            label="Color"
        ),

        gr.Dropdown(
            ["Silk", "Cotton", "Velvet", "Chiffon", "Organza"],
            value="Silk",
            label="Fabric"
        )
    ],

    outputs=gr.Textbox(
        label="✨ Generated Fashion Design",
        lines=20
    ),

    title="👗 AI Fashion Design Generator",

    description="Enter your requirements and generate an AI fashion design."
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://dade4a25719a4ab04c.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://dade4a25719a4ab04c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
